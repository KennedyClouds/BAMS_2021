# %% [markdown]
# This code produces Fig. 3 of Kennedy et al. (2021) in BAMS. It takes multiple composite images from OSCRE and adds annotation.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

BASE_DIR = 'pictures/'
files = ['OSCRE_panel_121519.png','OSCRE_panel_021220.png','OSCRE_panel_040220.png']
labels = ['(a)','(b)','(c)']
clabels = ['black','black','black']
titles = ['15 December 2019','12 February 2020','2 April 2020']
fig = plt.figure(figsize=(8,7),dpi=300,facecolor='white')
for i in range(1, 4):
    fig.add_subplot(3, 1, i)
    img=mpimg.imread(BASE_DIR+files[i-1])
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.text(10, -30, labels[i-1], fontsize=12,weight='bold',color="black")
    plt.title(titles[i-1],fontweight="bold",fontsize=12)
    plt.text(1825, 660, '1 cm', fontsize=10,weight='bold',color='white')

#plt.savefig('Fig03_OSCRE_PANEL.png', dpi=300, bbox_inches='tight')
#plt.savefig('Fig03_OSCRE_PANEL.pdf', format='pdf', bbox_inches='tight')
plt.show()
